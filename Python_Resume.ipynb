# %%
# Text Variables
Header = '>>>This resume is generated entirely using Python.'
Name = 'SHRADDHA PANDE'
Title = 'Software Developer'
Contact = ' Pune, Maharashtra\n\n 9403773955\n\n shraddha.p.pande@gmail.com\n\n linkedin.com/in/shraddha-pande\n\n https://github.com/shraddhapp\n'

ProfileSummary = 'PROFILE SUMMARY:'
SummaryDesc = 'A Software Engineer having ~2 years of experience in Application\n Development and enhancement who has worked in agile practices and\n having knowledge of Object-Oriented Programming with Python, C++\n and well conversant with the concepts of Core Java, JavaScript.'

#Experience Section

WorkHeader = 'PROFESSIONAL EXPERIENCE'

#Comapny 1
WorkOneTitle = 'HCL(Transitioned as a part of Strategic parternship between DELL-HCL)'
WorkOnePosition = 'Apr 2021- Present'

#Comapny 2
WorkTwoTitle = 'DELL EMC – Pune, MH'
WorkTwoPosition = 'Software Engineer - Sept 2019 - March 2021'
WorkTwoProject = 'Product: Data Protection Advisor (DPA)'
WorkTwoDesc = '''A Platform for performing reporting and analytics on a data protection\nenvironment.This solution can monitor technologies including backup \nsoftware,storage array replication, servers, databases,and virtual infrastructures.\nContribution-'''
WorkTwoContribution = '''• Enhanced the existing data collection requests to collect the information \n   from DPA-supported backup and storage software.\n• Worked on improving the Report engine interactions via REST APIs
• Converted the configuration of global settings for Reports form FLEX to HTML\n• Provided fixes, workarounds for various customer escalations
• Involved in customer interactions understanding the requirements and \n   interacting across the teams for demonstrations
'''
WorkTwoTechnologies = 'Technologies Used: Python, C++, JavaScript'

#Comapny 3
WorkThreeTitle = 'Symantec Software – Pune, MH'
WorkThreeTime = 'Intern - Jan 2019- June 2019'
WorkThreeProject = 'Product: Endpoint Detection and Response (EDR)'
WorkThreeDesc = '''A Plugin to the EDR which visualizes threats and gives detailed overview of \nwhat sequence of activities have occurred in the current system/network which \ncaused threat. An EDR dashboard will track, analyze, and display the status of
the system with the help of various graphs, charts, and timelines.'''
WorkThreeTechnologies = 'Technologies Used: Java, JavaScript, Elasticsearch, Kibana, AngularJS'

#Projects
ProjectHeader = 'ACADEMIC PROJECTS'
ProjectOneTitle = 'Crop Prediction Using Machine Learning and IOT'
ProjectOneDesc = "An application which uses machine learning techniques for classification,\napplied to Data responsible to predict the type of crop can grow in the field.\nTechnologies used: Java, Python, Machine Learning, IoT"

#Education
EduHeader = 'EDUCATION'
EduOneTitle = 'Master of Computer Applications (MCA) -2019'
EduOneCollege = 'Vishwakarma Institute of Technology - Pune, MH'
EduOneMarks = '• Post Graduated with 82.71%'

EduTwoTitle = 'Bachelor of Computer Science (BCS) -2016'
EduTwoCollege = 'H.P.T. Arts & R.Y.K. Science College - Nashik, MH'
EduTwoMarks = '• Graduated with 67.42%'

SkillsHeader = 'TECHNICAL SKILLS'
SkillsLangTitle = 'Languages:'
SkillsLangList = 'Python, C++, Core Java, JavaScript,\nHTML,CSS'
SkillsDBTitle = 'Databases:'
SkillsDBList = 'SQL, Elasticsearch'
SkillsToolsTitle = 'Tools and IDEs:'
SkillsToolsList = 'VS Code, Eclipse'
SkillsVCSTitle = 'Version Control Systems:'
SkillsVCSList = 'GitHub, Bitbucket'

ExtrasTitle = 'ACHIEVEMENTS AND \nEXTRACURRICULAR'
ExtrasDesc = '''• Awarded with ‘Best Outgoing\n   Student’ of VIT, 2019.\n\n• Project leader on multiple\n   assignments during\n   post-graduation.
\n• Winner of Blind coding\n   competition held at VIT, Pune.\n\n• Attended a workshop on \n  “Machine Learning and Data\n   Analytics using Python”\n   held at VIT, Pune.
\n• Participation in hackathons.\n\n• Member of various ERGs and\n   CSR activities in DELL.
'''

CodeTitle = 'View Portfolio'

# Setting style for bar graphs
import matplotlib.pyplot as plt
# %matplotlib inline

# set font
plt.rcParams['font.family'] = 'sans'
plt.rcParams['font.sans-serif'] = 'STIXGeneral'

fig, ax = plt.subplots(figsize=(8.5, 11))

# Decorative Lines
ax.axvline(x=.5, ymin=0, ymax=1, color='#007ACC', alpha=0.0, linewidth=50)
plt.axvline(x=.99, color='#000000', alpha=0.5, linewidth=300)
plt.axhline(y=.79, xmin=0, xmax=1, color='#ffffff', linewidth=3)

# set background color
#ax.set_facecolor('white')

# remove axes
plt.axis('off')

# add text
plt.annotate(Header, (.02,.98), weight='regular', fontsize=8, alpha=.6)
plt.annotate(Name, (.02,.94), weight='bold', fontsize=20)
plt.annotate(Title, (.02,.91), weight='regular', fontsize=12)
plt.annotate(Contact, (.72,.803), weight='regular', fontsize=9.5, color='#ffffff')

plt.annotate(ProfileSummary, (.02,.87), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(SummaryDesc, (.02,.80), weight='regular', fontsize=9)

#Adding Work Experience
plt.annotate(WorkHeader, (.02,.76), weight='bold', fontsize=10, color='#58C1B2')

plt.annotate(WorkOneTitle, (.02,.730), weight='bold', fontsize=9)
plt.annotate(WorkOnePosition, (.02,.710), weight='bold', fontsize=9, alpha=.6)

plt.annotate(WorkTwoTitle, (.02,.690), weight='bold', fontsize=9)
plt.annotate(WorkTwoPosition, (.02,.670), weight='bold', fontsize=9, alpha=.6)
plt.annotate(WorkTwoProject, (.02,.650), weight='bold', fontsize=8.5)
plt.annotate(WorkTwoDesc, (.02,.580), weight='regular', fontsize=9)
plt.annotate(WorkTwoContribution, (.04,.455), weight='regular', fontsize=9)
plt.annotate(WorkTwoTechnologies, (.02,.448), weight='regular', fontsize=9)

plt.annotate(WorkThreeTitle, (.02,.415), weight='bold', fontsize=9.4)
plt.annotate(WorkThreeTime, (.02,.395), weight='bold', fontsize=9, alpha=.6)
plt.annotate(WorkThreeProject, (.02,.375), weight='bold', fontsize=8.5)
plt.annotate(WorkThreeDesc, (.02,.310), weight='regular', fontsize=9)
plt.annotate(WorkThreeTechnologies, (.02,.283), weight='regular', fontsize=9)

#Adding Projects
plt.annotate(ProjectHeader, (.02,.250), weight='bold', fontsize=10, color='#58C1B2')

plt.annotate(ProjectOneTitle, (.02,.220), weight='bold', fontsize=9)
plt.annotate(ProjectOneDesc, (.02,.170), weight='regular', fontsize=9)

#Add Education
plt.annotate(EduHeader, (.02,.140), weight='bold', fontsize=10, color='#58C1B2')
plt.annotate(EduOneTitle, (.02,.120), weight='bold', fontsize =9)
plt.annotate(EduOneCollege, (.02,.105), weight='regular', fontsize=9)
plt.annotate(EduOneMarks, (.04,.085), weight='regular', fontsize=9)

plt.annotate(EduTwoTitle, (.02,.060), weight='bold', fontsize=9)
plt.annotate(EduTwoCollege, (.02,.045), weight='regular', fontsize=9)
plt.annotate(EduTwoMarks, (.04,.025), weight='regular', fontsize=9)

#Adding Skills
plt.annotate(SkillsHeader, (.7,.75), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(SkillsLangTitle, (.7,.72), weight='bold', fontsize=9.5, color='#ffffff')
plt.annotate(SkillsLangList, (.7,.68), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(SkillsDBTitle, (.7,.65), weight='bold', fontsize=9.5, color='#ffffff')
plt.annotate(SkillsDBList, (.7,.63), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(SkillsToolsTitle, (.7,.60), weight='bold', fontsize=9.5, color='#ffffff')
plt.annotate(SkillsToolsList, (.7,.58), weight='regular', fontsize=9, color='#ffffff')
plt.annotate(SkillsVCSTitle, (.7,.55), weight='bold', fontsize=9.5, color='#ffffff')
plt.annotate(SkillsVCSList, (.7,.53), weight='regular', fontsize=9, color='#ffffff')

#Extras
plt.annotate(ExtrasTitle, (.7,.46), weight='bold', fontsize=10, color='#ffffff')
plt.annotate(ExtrasDesc, (.7,.058), weight='regular', fontsize=10, color='#ffffff')

#add qr code
from matplotlib.offsetbox import TextArea, DrawingArea, OffsetImage, AnnotationBbox
import matplotlib.image as mpimg

location_icon = mpimg.imread('location.png')
imagebox = OffsetImage(location_icon, zoom=0.030)
ab_l = AnnotationBbox(imagebox, (0.7, .960), frameon = False)
ax.add_artist(ab_l)

phone_icon = mpimg.imread('phone.png')
imagebox = OffsetImage(phone_icon, zoom=0.021)
ab_p = AnnotationBbox(imagebox, (0.7, .930), frameon = False)
ax.add_artist(ab_p)

mail_icon = mpimg.imread('mail.png')
imagebox = OffsetImage(mail_icon, zoom=0.021)
ab_m = AnnotationBbox(imagebox, (0.7, .894), frameon = False)
ax.add_artist(ab_m)

linkedin_icon = mpimg.imread('linkedin.png')
imagebox = OffsetImage(linkedin_icon, zoom=0.050)
ab_l = AnnotationBbox(imagebox, (0.7, .860), frameon = False)
ax.add_artist(ab_l)

github_icon = mpimg.imread('github.png')
imagebox = OffsetImage(github_icon, zoom=0.0245)
ab_g = AnnotationBbox(imagebox, (0.7, 0.820), frameon = False)
ax.add_artist(ab_g)


#plt.savefig("C:\\Users\\pandes25\\Documents\\Imp\\Resume\\shraddha_resume.png", dpi=2000, bbox_inches='tight')
plt.savefig("C:\\Users\\pandes25\\Documents\\Imp\\Resume\\Resume_Shraddha_Pande.pdf", dpi=8000, bbox_inches='tight')
